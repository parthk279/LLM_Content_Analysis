# %%
from dotenv import load_dotenv
load_dotenv()
import os

api_key = os.getenv("OPENAI_API_KEY")

# %%
import streamlit as st

st.title("LLM-Powered Content Analysis Automation")
st.write("This is a Streamlit interface for automating content analysis with chatbots.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 import streamlit as st
#       3 st.title("LLM-Powered Content Analysis Automation")
#       4 st.write("This is a Streamlit interface for automating content analysis with chatbots.")
#
# ModuleNotFoundError: No module named 'streamlit'

# %%
pip install streamlit
# Out:
# ...
#   Using cached streamlit-1.40.0-py2.py3-none-any.whl (8.6 MB)
# ...
#   Using cached blinker-1.8.2-py3-none-any.whl (9.5 kB)
# ...
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# ...
#   Using cached altair-5.4.1-py3-none-any.whl (658 kB)
# ...
#   Using cached protobuf-5.28.3-cp38-abi3-macosx_10_9_universal2.whl (414 kB)
# ...
#   Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# ...
#   Using cached pyarrow-18.0.0.tar.gz (1.1 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Using cached rich-13.9.4-py3-none-any.whl (242 kB)
# ...
#   Using cached tenacity-9.0.0-py3-none-any.whl (28 kB)
# ...
#   Using cached narwhals-1.13.2-py3-none-any.whl (198 kB)
# ...
#   Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# ...
#   Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# ...
#   Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# ...
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# ...
